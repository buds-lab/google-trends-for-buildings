# %%
import pandas as pd
import numpy as np
import json
from sklearn.metrics import r2_score
import os
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
import plotly
import chart_studio.plotly as py
import plotly.express as px
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
path_dataset =r'C:\Users\patri\Google trends for buildings\Dataset'
path_submissions =r'D:\Temp\20200809\Google trends for buildings\Top50 submissions in GEPIII'

# %%
test_df = pd.read_pickle(os.path.join(path_dataset, 'test_df.pickle'))
test_df
# Out:
#             row_id  building_id  meter           timestamp bldgID_meter
# 0                0            0      0 2017-01-01 00:00:00          0_0
# 1                1            1      0 2017-01-01 00:00:00          1_0
# 2                2            2      0 2017-01-01 00:00:00          2_0
# 3                3            3      0 2017-01-01 00:00:00          3_0
# 4                4            4      0 2017-01-01 00:00:00          4_0
# ...            ...          ...    ...                 ...          ...
# 41697595  41697595         1444      0 2018-05-09 07:00:00       1444_0
# 41697596  41697596         1445      0 2018-05-09 07:00:00       1445_0
# 41697597  41697597         1446      0 2018-05-09 07:00:00       1446_0
# 41697598  41697598         1447      0 2018-05-09 07:00:00       1447_0
# 41697599  41697599         1448      0 2018-05-09 07:00:00       1448_0
#
# [41697600 rows x 5 columns]

# %%
df_clustering_output = pd.read_pickle(os.path.join(path_dataset, 'df_clustering_output.pickle'))
df_clustering_output['bldgID_meter'] = df_clustering_output['building_id'].astype('str') + '_' + df_clustering_output['meter'].astype('str')
df_clustering_output
# Out:
#                    merged_id  ClusterNo  site_id  building_id  meter  \
# 0         site0_bldg0_meter0          1        0            0      0
# 1         site0_bldg1_meter0          1        0            1      0
# 2         site0_bldg2_meter0          3        0            2      0
# 3         site0_bldg3_meter0          1        0            3      0
# 4         site0_bldg4_meter0          1        0            4      0
# ...                      ...        ...      ...          ...    ...
# 2375  site15_bldg1444_meter0          4       15         1444      0
# 2376  site15_bldg1445_meter0          0       15         1445      0
# 2377  site15_bldg1446_meter0          3       15         1446      0
# 2378  site15_bldg1447_meter0          4       15         1447      0
# 2379  site15_bldg1448_meter0          3       15         1448      0
#
#      bldgID_meter
# 0             0_0
# 1             1_0
# 2             2_0
# 3             3_0
# 4             4_0
# ...           ...
# 2375       1444_0
# 2376       1445_0
# 2377       1446_0
# 2378       1447_0
# 2379       1448_0
#
# [2380 rows x 6 columns]

# %%
df_daily_merged = pd.read_pickle(os.path.join(path_dataset, 'df_daily_merged.pickle'))
df_daily_merged_pivot = df_daily_merged.pivot_table(columns='keyword', index=['geo_id', 'date'], values='trend').reset_index()
df_daily_merged_pivot
# Out:
# keyword geo_id       date  Adobe  Google Docs  Microsoft Office
# 0           CA 2016-01-03  76.00        13.53             23.20
# 1           CA 2016-01-04  83.00        24.19             42.34
# 2           CA 2016-01-05  82.00        32.39             42.34
# 3           CA 2016-01-06  88.00        30.34             48.14
# 4           CA 2016-01-07  83.00        31.98             58.00
# ...        ...        ...    ...          ...               ...
# 11636       US 2020-07-18  42.12        11.60             26.13
# 11637       US 2020-07-19  38.71        13.44             23.76
# 11638       US 2020-07-20  74.26        19.95             52.80
# 11639       US 2020-07-21  79.00        20.16             57.42
# 11640       US 2020-07-22  78.21        19.95             58.74
#
# [11641 rows x 5 columns]

# %%
df_solution = pd.read_csv(os.path.join(path_dataset, 'solution.csv'))
df_solution = df_solution.rename(columns={'meter_reading':'meter_reading_groundTruth'})
df_solution
# Out:
#             row_id  meter_reading_groundTruth    Usage
# 0                0                   173.3700   Public
# 1                1                    53.5127   Public
# 2                2                     6.1430   Public
# 3                3                   101.7010   Public
# 4                4                  1141.2400   Public
# ...            ...                        ...      ...
# 41697595  41697595                 -9999.0000  Ignored
# 41697596  41697596                 -9999.0000  Ignored
# 41697597  41697597                 -9999.0000  Ignored
# 41697598  41697598                 -9999.0000  Ignored
# 41697599  41697599                 -9999.0000  Ignored
#
# [41697600 rows x 3 columns]

# %%
# Get the list of paths of hourly data (.csv)
list_sub = []

for file in os.listdir(path_submissions):
    list_sub.append(os.path.join(path_submissions, file))
        
list_sub
# Out:
# ['D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13577404.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13768618.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13768660.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13806350.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13808838.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13810582.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13812777.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13819396.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13821697.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13821715.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13821811.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13824794.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13836206.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13837629.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13840907.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13843576.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13846739.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13846982.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13851881.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13852585.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13852810.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13853013.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13854058.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13854746.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13855061.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13855445.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13856190.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13857716.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13858760.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13859685.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13859917.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13861960.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13862458.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13862516.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13862695.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13862717.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13862875.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13863380.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13863401.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13864060.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13864638.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13865189.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13865192.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13865584.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13865820.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13866063.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13866280.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13866386.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13866389.pickle.gz',
#  'D:\\Temp\\20200809\\Google trends for buildings\\Top50 submissions in GEPIII\\13866501.pickle.gz']

# %%
site_id = 13
meter = 0
ClusterNo = 6

path_temp = list_sub[1]

df_submission_temp = pd.read_pickle(path_temp)

list_Cluster = df_clustering_output[(df_clustering_output['site_id']==site_id)&(df_clustering_output['meter']==meter)&(df_clustering_output['ClusterNo']==ClusterNo)]['bldgID_meter'].to_list()
idx_Cluster = test_df[test_df['bldgID_meter'].isin(list_Cluster)].index

df_submission_temp = df_submission_temp.loc[idx_Cluster]
df_submission_temp = df_submission_temp.merge(test_df, on='row_id')
df_submission_temp = df_submission_temp.merge(df_solution, on='row_id')

df_plot = df_submission_temp.pivot_table(columns='bldgID_meter', values='meter_reading_groundTruth', index='timestamp')
df_plot = df_plot[df_plot>0]
df_plot = (df_plot - df_plot.mean())/df_plot.std()
df_plot.plot(figsize=(15,5),alpha=0.1,legend=False, ylim=(-3, 5),color='black')

bldgID_meter = df_submission_temp['bldgID_meter'].unique()[0]
df_temp = df_submission_temp[df_submission_temp['bldgID_meter']==bldgID_meter].copy()
df_temp = df_temp.set_index('timestamp')[['meter_reading', 'meter_reading_groundTruth']].sort_index()
df_temp = df_temp[df_temp>0]
df_temp.iplot()
# Out:
# <div>
#
#
#             <div id="501910d0-b34c-4762-93a9-bc8fbf704560" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("501910d0-b34c-4762-93a9-bc8fbf704560")) {
#                     Plotly.newPlot(
#                         '501910d0-b34c-4762-93a9-bc8fbf704560',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name":